# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import h5py
from scipy import interpolate
from ccfj import GetStationPairs
import pandas as pd
import yaml
import geopandas as gp
import openpyxl
from openpyxl import load_workbook
from concurrent.futures import ThreadPoolExecutor

from scipy.interpolate import make_interp_spline
from scipy.stats import ks_2samp
from scipy.spatial import ConvexHull

# %%
import sys
sys.path.append(r'../tools_F-J/')
from toollib_standard import maplib
from toollib_standard import mathlib
from toollib_standard import filelib
from toollib_standard import stacklib
from toollib_standard import plotlib

# %%
with open('a-project_repar.yml', 'r', encoding='utf-8') as f:
    proj = yaml.load(f.read(), Loader=yaml.FullLoader)
name_project = proj['name']
#name_project = 'project_repartrition/output_repar_03-01/'               # Harmon server
name_project
# Out:
# 'project_repartition_v3.0/output_repar_test/'

# %%
with open('0_config.yml', 'r', encoding='utf-8') as f:
    dir_config = yaml.load(f.read(), Loader=yaml.FullLoader)
dir_project_workspace = dir_config['dir_project_workspace']
dir_CC_workspace = dir_config['dir_CC_workspace']
print('dir_CC_workspace: ', dir_CC_workspace)
print('dir_project_workspace: ', dir_project_workspace)
dir_project = os.path.join(dir_project_workspace, name_project)
print('dir_project: ', dir_project)
# Out:
# dir_CC_workspace:  /shdisk/rem2/Harmon/F-J/San/
# dir_project_workspace:  /shdisk/rem2/Harmon/F-J/San/
# dir_project:  /shdisk/rem2/Harmon/F-J/San/project_repartition_v3.0/output_repar_test/

# %%
filename = dir_project+'Basic_info.yml'
with open(filename, 'r', encoding='utf-8') as f:
    info_basic = yaml.load(f.read(), Loader=yaml.FullLoader)
filename_bi = dir_project+'Basic_info.npy'
info_basic_bi = np.load(filename_bi, allow_pickle='TRUE').item()      # setting dictionary

# %%
name_project_probes = info_basic['name_project_probes']
name_project_targets = info_basic['name_project_targets']
dir_project_probes = os.path.join(dir_project_workspace, name_project_probes)
dir_project_targets = os.path.join(dir_project_workspace, name_project_targets)
print('dir_project_probes: ', dir_project_probes)
print('dir_project_targets: ', dir_project_targets)
# Out:
# dir_project_probes:  /shdisk/rem2/Harmon/F-J/San/project/output_FJSJ_17-01/
# dir_project_targets:  /shdisk/rem2/Harmon/F-J/San/project/output_FJSJ_17-03/

# %%
filename = dir_project_probes+'Basic_info.yml'
with open(filename, 'r', encoding='utf-8') as f:
    info_basic_probes = yaml.load(f.read(), Loader=yaml.FullLoader)
filename_bi = dir_project_probes+'Basic_info.npy'
info_basic_bi_probes = np.load(filename_bi, allow_pickle='TRUE').item()      # setting dictionary

filename = dir_project_targets+'Basic_info.yml'
with open(filename, 'r', encoding='utf-8') as f:
    info_basic_targets = yaml.load(f.read(), Loader=yaml.FullLoader)

# %%
probes = info_basic_probes['key_subworks']
targets = info_basic_targets['key_subworks']

# %%
dir_image = dir_project+info_basic['dir_image']
dir_disp_probes  = dir_project_probes + info_basic_probes['dir_disp'] 
print('dir_image: ', dir_image)
print('dir_disp: ', dir_disp_probes)
# Out:
# dir_image:  /shdisk/rem2/Harmon/F-J/San/project_repartition_v3.0/output_repar_test/image_test/
# dir_disp:  /shdisk/rem2/Harmon/F-J/San/project/output_FJSJ_17-01/autopick17-01//

# %%
stalistname_all = info_basic_probes['stalistname_all']
stainfo = pd.read_excel(stalistname_all)
nsta_all = len(stainfo.iloc[:,0])
StationPairs_all = GetStationPairs(nsta_all)
nPairs_all = int(len(StationPairs_all)/2)
stalist_all = stainfo['Station'].tolist()
lat_all = stainfo['latitude'].tolist() 
lon_all = stainfo['longitude'].tolist()

# %%
stalistname = dir_project_probes+ info_basic_probes['stalistname']
stainfo_probes = pd.read_excel(stalistname,sheet_name=None)
stalistname = dir_project_targets+ info_basic_targets['stalistname']
stainfo_targets = pd.read_excel(stalistname,sheet_name=None)

# %%
loc_probes = pd.read_excel(dir_project_probes + 'subwork_location.xlsx',sheet_name='location')

# %%
f = info_basic_bi_probes['f']
c = np.linspace(info_basic_probes['c_min'],info_basic_probes['c_max'],info_basic_probes['c_num'])

# %%
faults = np.load('clark_faults.npy', allow_pickle='TRUE').item()

# %% [markdown]
# ### Cluster

# %%
phase_mean = info_basic_bi['phase_mean']
ks_f_range = info_basic['ks_f_range']

# %%
def extract_probes(key_subwork):
    global dir_project
    global dir_project_probes
    global dir_project_targets
    global probes
    global stainfo_targets

    stas = stainfo_targets[key_subwork]['Station'].tolist()
    # 生成sta的包络
    #hull_sta = ConvexHull(stainfo_targets[key_subwork][['Longitude','Latitude']])

    stas2key = [sta[1:3]+'-'+sta[3:] for sta in stas]
    probes_this = []
    for sta in stas2key:
        if sta in probes:
            probes_this.append(sta)
    return probes_this

# %%
def find_nearest(lon_this,lat_this,lon_all,lat_all):
    lon_all = np.array(lon_all)
    lat_all = np.array(lat_all)
    lon_all = lon_all.reshape(-1,1)
    lat_all = lat_all.reshape(-1,1)
    dist = np.sqrt((lon_all-lon_this)**2+(lat_all-lat_this)**2)
    min_dist = np.min(dist)
    index = np.where(dist==min_dist)[0][0]
    return index

# %%
def cluster_filter(target):
    global flag_err
    global flag_plot
    global dir_image
    # extract all disp
    probes_this = extract_probes(target)
    stations = set()
    for probe in probes_this:
        stations_this = [station for station in stainfo_probes[probe]['Station'].tolist()]
        stations = stations.union(set(stations_this))
        
    stations = list(stations)

    lon_this = []
    lat_this = []
    for probe in probes_this:
        lon_this.append(loc_probes['lon_centroid'][probes.index(probe)])
        lat_this.append(loc_probes['lat_centroid'][probes.index(probe)])
    # 读取全部autopick dispersion curves
    disp_all = {}
    for probe in probes_this:
        file_ds = dir_project_probes  + info_basic_probes['dir_disp'] + 'autopick_'+probe+'.txt'
        disp = np.loadtxt(file_ds,delimiter=',')
        index = np.where((disp[:,0]>=ks_f_range[0]) & (disp[:,0]<=ks_f_range[1]))[0]
        disp_all[probe] = disp[index,:]
    phase_this = [phase_mean[probe] for probe in probes_this]

    # find central probe and cluster based on it
    lon_centroid = np.mean(lon_this)
    lat_centroid = np.mean(lat_this)
    index = find_nearest(lon_centroid,lat_centroid,lon_this,lat_this)
    c_ref = phase_this[index]
    probe_ref = probes_this[index]
    
    phase_sort = np.sort(phase_this)
    index_phase = range(len(phase_sort))
    probe_accept = []
    phase_accept = []
    lon_accept = []
    lat_accept = []
    for probe in probes_this:
        if phase_mean[probe] >= c_ref*(1-flag_err) and phase_mean[probe] <= c_ref*(1+flag_err):
            probe_accept.append(probe)
            lon_accept.append(loc_probes['lon_centroid'][probes.index(probe)])
            lat_accept.append(loc_probes['lat_centroid'][probes.index(probe)])
            phase_accept.append(phase_mean[probe])

    if flag_plot == 1:
        fig = plt.figure(figsize=(21,6))
        ax = fig.add_subplot(131)
        ax.scatter(index_phase,phase_sort,c='k',s=20)
        ax.axhline(y=c_ref,color='b',ls='--',label='central mean')
        ax.axhline(y=c_ref*(1-flag_err),color='r',ls='--',label='tolerance range')
        ax.axhline(y=c_ref*(1+flag_err),color='r',ls='--')
        ax.set_xlabel('probe index')
        ax.set_ylabel('phase velocity (km/s)')
        ax.legend()

        ax = fig.add_subplot(132)
        ax.scatter(lon_all,lat_all,c='k',s=1)
        im = ax.scatter(lon_this,lat_this,c=phase_this,s=20,cmap='jet')
        ax.scatter(lon_centroid,lat_centroid,c='k',s=60,marker='*',label = 'centroid')
        #设置colorbar范围
        im.set_clim(vmin=min(phase_this),vmax=max(phase_this))
        ax.set_xlabel('Longitude')
        ax.set_ylabel('Latitude')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(target)
        for i in range(len(faults)):
            ax.plot(faults['clark'+str(i+1)]['lon'], faults['clark'+str(i+1)]['lat'], 'k--',lw=1)
        fig.colorbar(im, ax=ax)
        ax.legend()
        """
        print('phase_max: ', max(phase_this))
        print('phase_min: ', min(phase_this))
        print('phase_bar: ', max(phase_this)-min(phase_this))
        print('phase_percent: ', (max(phase_this)-min(phase_this))/np.mean(phase_this)*100, '%')
        """
        ax = fig.add_subplot(133)
        ax.scatter(lon_all,lat_all,c='k',s=1)
        im = ax.scatter(lon_accept,lat_accept,c=phase_accept,s=20,cmap='jet')
        ax.scatter(lon_centroid,lat_centroid,c='k',s=60,marker='*',label = 'centroid')
        im.set_clim(vmin=min(phase_this),vmax=max(phase_this))
        ax.set_xlabel('Longitude')
        ax.set_ylabel('Latitude')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(target)
        for i in range(len(faults)):
            ax.plot(faults['clark'+str(i+1)]['lon'], faults['clark'+str(i+1)]['lat'], 'k--',lw=1)
        fig.colorbar(im, ax=ax)
        ax.legend()
        plt.tight_layout()
        plt.savefig(dir_image+'cluster_filter_'+target+'.png',dpi=100)
        #plt.close()
    print('cluster_filter: ', target)
    return probe_accept,lon_accept,lat_accept

# %%
probe_accept_all = {}
lon_accept_all = {}
lat_accept_all = {}

# %%
flag_err = 0.1
flag_plot = 0
for target in targets:
    probe_accept_all[target],lon_accept_all[target],lat_accept_all[target] = cluster_filter(target)
# Out:
# cluster_filter:  09-04
# cluster_filter:  10-04
# cluster_filter:  11-04
# cluster_filter:  12-04
# cluster_filter:  13-04
# cluster_filter:  14-04
# cluster_filter:  15-04
# cluster_filter:  16-04
# cluster_filter:  17-04
# cluster_filter:  18-04
# cluster_filter:  19-04
# cluster_filter:  20-04
# cluster_filter:  21-04
# cluster_filter:  22-04
# cluster_filter:  23-04
# cluster_filter:  24-04
# cluster_filter:  25-04
# cluster_filter:  26-04
# cluster_filter:  27-04
# cluster_filter:  28-04
# cluster_filter:  29-04
# cluster_filter:  30-04
# cluster_filter:  31-04
# cluster_filter:  32-04
# cluster_filter:  33-04
# cluster_filter:  34-04
# cluster_filter:  35-04
# cluster_filter:  36-04
# cluster_filter:  37-04
# cluster_filter:  38-04
# cluster_filter:  39-04
# cluster_filter:  40-04
# cluster_filter:  41-04
# cluster_filter:  42-04
# cluster_filter:  43-04
# cluster_filter:  44-04
# cluster_filter:  45-04
# cluster_filter:  46-04
# cluster_filter:  47-04
# cluster_filter:  48-04
# cluster_filter:  49-04
# cluster_filter:  50-04
# cluster_filter:  51-04
# cluster_filter:  52-04
# cluster_filter:  09-05
# cluster_filter:  10-05
# cluster_filter:  11-05
# cluster_filter:  12-05
# cluster_filter:  13-05
# cluster_filter:  14-05
# cluster_filter:  15-05
# cluster_filter:  16-05
# cluster_filter:  17-05
# cluster_filter:  18-05
# cluster_filter:  19-05
# cluster_filter:  20-05
# cluster_filter:  21-05
# cluster_filter:  22-05
# cluster_filter:  23-05
# cluster_filter:  24-05
# cluster_filter:  25-05
# cluster_filter:  26-05
# cluster_filter:  27-05
# cluster_filter:  28-05
# cluster_filter:  29-05
# cluster_filter:  30-05
# cluster_filter:  31-05
# cluster_filter:  32-05
# cluster_filter:  33-05
# cluster_filter:  34-05
# cluster_filter:  35-05
# cluster_filter:  36-05
# cluster_filter:  37-05
# cluster_filter:  38-05
# cluster_filter:  39-05
# cluster_filter:  40-05
# cluster_filter:  41-05
# cluster_filter:  42-05
# cluster_filter:  43-05
# cluster_filter:  44-05
# cluster_filter:  45-05
# cluster_filter:  46-05
# cluster_filter:  47-05
# cluster_filter:  48-05
# cluster_filter:  49-05
# cluster_filter:  50-05
# cluster_filter:  51-05
# cluster_filter:  52-05
# cluster_filter:  09-06
# cluster_filter:  10-06
# cluster_filter:  11-06
# cluster_filter:  12-06
# cluster_filter:  13-06
# cluster_filter:  14-06
# cluster_filter:  15-06
# cluster_filter:  16-06
# cluster_filter:  17-06
# cluster_filter:  18-06
# cluster_filter:  19-06
# cluster_filter:  20-06
# cluster_filter:  21-06
# cluster_filter:  22-06
# cluster_filter:  23-06
# cluster_filter:  24-06
# cluster_filter:  25-06
# cluster_filter:  26-06
# cluster_filter:  27-06
# cluster_filter:  28-06
# cluster_filter:  29-06
# cluster_filter:  30-06
# cluster_filter:  31-06
# cluster_filter:  32-06
# cluster_filter:  33-06
# cluster_filter:  34-06
# cluster_filter:  35-06
# cluster_filter:  36-06
# cluster_filter:  37-06
# cluster_filter:  38-06
# cluster_filter:  39-06
# cluster_filter:  40-06
# cluster_filter:  41-06
# cluster_filter:  42-06
# cluster_filter:  43-06
# cluster_filter:  44-06
# cluster_filter:  45-06
# cluster_filter:  46-06
# cluster_filter:  47-06
# cluster_filter:  48-06
# cluster_filter:  49-06
# cluster_filter:  50-06
# cluster_filter:  51-06
# cluster_filter:  52-06
# cluster_filter:  09-07
# cluster_filter:  10-07
# cluster_filter:  11-07
# cluster_filter:  12-07
# cluster_filter:  13-07
# cluster_filter:  14-07
# cluster_filter:  15-07
# cluster_filter:  16-07
# cluster_filter:  17-07
# cluster_filter:  18-07
# cluster_filter:  19-07
# cluster_filter:  20-07
# cluster_filter:  21-07
# cluster_filter:  22-07
# cluster_filter:  23-07
# cluster_filter:  24-07
# cluster_filter:  25-07
# cluster_filter:  26-07
# cluster_filter:  27-07
# cluster_filter:  28-07
# cluster_filter:  29-07
# cluster_filter:  30-07
# cluster_filter:  31-07
# cluster_filter:  32-07
# cluster_filter:  33-07
# cluster_filter:  34-07
# cluster_filter:  35-07
# cluster_filter:  36-07
# cluster_filter:  37-07
# cluster_filter:  38-07
# cluster_filter:  39-07
# cluster_filter:  40-07
# cluster_filter:  41-07
# cluster_filter:  42-07
# cluster_filter:  43-07
# cluster_filter:  44-07
# cluster_filter:  45-07
# cluster_filter:  46-07
# cluster_filter:  47-07
# cluster_filter:  48-07
# cluster_filter:  49-07
# cluster_filter:  50-07
# cluster_filter:  51-07
# cluster_filter:  52-07
# cluster_filter:  09-08
# cluster_filter:  10-08
# cluster_filter:  11-08
# cluster_filter:  12-08
# cluster_filter:  13-08
# cluster_filter:  14-08
# cluster_filter:  15-08
# cluster_filter:  16-08
# cluster_filter:  17-08
# cluster_filter:  18-08
# cluster_filter:  19-08
# cluster_filter:  20-08
# cluster_filter:  21-08
# cluster_filter:  22-08
# cluster_filter:  23-08
# cluster_filter:  24-08
# cluster_filter:  25-08
# cluster_filter:  26-08
# cluster_filter:  27-08
# cluster_filter:  28-08
# cluster_filter:  29-08
# cluster_filter:  30-08
# cluster_filter:  31-08
# cluster_filter:  32-08
# cluster_filter:  33-08
# cluster_filter:  34-08
# cluster_filter:  35-08
# cluster_filter:  36-08
# cluster_filter:  37-08
# cluster_filter:  38-08
# cluster_filter:  39-08
# cluster_filter:  40-08
# cluster_filter:  41-08
# cluster_filter:  42-08
# cluster_filter:  43-08
# cluster_filter:  44-08
# cluster_filter:  45-08
# cluster_filter:  46-08
# cluster_filter:  47-08
# cluster_filter:  48-08
# cluster_filter:  49-08
# cluster_filter:  50-08
# cluster_filter:  51-08
# cluster_filter:  52-08
# cluster_filter:  09-09
# cluster_filter:  10-09
# cluster_filter:  11-09
# cluster_filter:  12-09
# cluster_filter:  13-09
# cluster_filter:  14-09
# cluster_filter:  15-09
# cluster_filter:  16-09
# cluster_filter:  17-09
# cluster_filter:  18-09
# cluster_filter:  19-09
# cluster_filter:  20-09
# cluster_filter:  21-09
# cluster_filter:  22-09
# cluster_filter:  23-09
# cluster_filter:  24-09
# cluster_filter:  25-09
# cluster_filter:  26-09
# cluster_filter:  27-09
# cluster_filter:  28-09
# cluster_filter:  29-09
# cluster_filter:  30-09
# cluster_filter:  31-09
# cluster_filter:  32-09
# cluster_filter:  33-09
# cluster_filter:  34-09
# cluster_filter:  35-09
# cluster_filter:  36-09
# cluster_filter:  37-09
# cluster_filter:  38-09
# cluster_filter:  39-09
# cluster_filter:  40-09
# cluster_filter:  41-09
# cluster_filter:  42-09
# cluster_filter:  43-09
# cluster_filter:  44-09
# cluster_filter:  45-09
# cluster_filter:  46-09
# cluster_filter:  47-09
# cluster_filter:  48-09
# cluster_filter:  49-09
# cluster_filter:  50-09
# cluster_filter:  51-09
# cluster_filter:  52-09
# cluster_filter:  09-10
# cluster_filter:  10-10
# cluster_filter:  11-10
# cluster_filter:  12-10
# cluster_filter:  13-10
# cluster_filter:  14-10
# cluster_filter:  15-10
# cluster_filter:  16-10
# cluster_filter:  17-10
# cluster_filter:  18-10
# cluster_filter:  19-10
# cluster_filter:  20-10
# cluster_filter:  21-10
# cluster_filter:  22-10
# cluster_filter:  23-10
# cluster_filter:  24-10
# cluster_filter:  25-10
# cluster_filter:  26-10
# cluster_filter:  27-10
# cluster_filter:  28-10
# cluster_filter:  29-10
# cluster_filter:  30-10
# cluster_filter:  31-10
# cluster_filter:  32-10
# cluster_filter:  33-10
# cluster_filter:  34-10
# cluster_filter:  35-10
# cluster_filter:  36-10
# cluster_filter:  37-10
# cluster_filter:  38-10
# cluster_filter:  39-10
# cluster_filter:  40-10
# cluster_filter:  41-10
# cluster_filter:  42-10
# cluster_filter:  43-10
# cluster_filter:  44-10
# cluster_filter:  45-10
# cluster_filter:  46-10
# cluster_filter:  47-10
# cluster_filter:  48-10
# cluster_filter:  49-10
# cluster_filter:  50-10
# cluster_filter:  51-10
# cluster_filter:  52-10
# cluster_filter:  09-11
# cluster_filter:  10-11
# cluster_filter:  11-11
# cluster_filter:  12-11
# cluster_filter:  13-11
# cluster_filter:  14-11
# cluster_filter:  15-11
# cluster_filter:  16-11
# cluster_filter:  17-11
# cluster_filter:  18-11
# cluster_filter:  19-11
# cluster_filter:  20-11
# cluster_filter:  21-11
# cluster_filter:  22-11
# cluster_filter:  23-11
# cluster_filter:  24-11
# cluster_filter:  25-11
# cluster_filter:  26-11
# cluster_filter:  27-11
# cluster_filter:  28-11
# cluster_filter:  29-11
# cluster_filter:  30-11
# cluster_filter:  31-11
# cluster_filter:  32-11
# cluster_filter:  33-11
# cluster_filter:  34-11
# cluster_filter:  35-11
# cluster_filter:  36-11
# cluster_filter:  37-11
# cluster_filter:  38-11
# cluster_filter:  39-11
# cluster_filter:  40-11
# cluster_filter:  41-11
# cluster_filter:  42-11
# cluster_filter:  43-11
# cluster_filter:  44-11
# cluster_filter:  45-11
# cluster_filter:  46-11
# cluster_filter:  47-11
# cluster_filter:  48-11
# cluster_filter:  49-11
# cluster_filter:  50-11
# cluster_filter:  51-11
# cluster_filter:  52-11
# cluster_filter:  09-12
# cluster_filter:  10-12
# cluster_filter:  11-12
# cluster_filter:  12-12
# cluster_filter:  13-12
# cluster_filter:  14-12
# cluster_filter:  15-12
# cluster_filter:  16-12
# cluster_filter:  17-12
# cluster_filter:  18-12
# cluster_filter:  19-12
# cluster_filter:  20-12
# cluster_filter:  21-12
# cluster_filter:  22-12
# cluster_filter:  23-12
# cluster_filter:  24-12
# cluster_filter:  25-12
# cluster_filter:  26-12
# cluster_filter:  27-12
# cluster_filter:  28-12
# cluster_filter:  29-12
# cluster_filter:  30-12
# cluster_filter:  31-12
# cluster_filter:  32-12
# cluster_filter:  33-12
# cluster_filter:  34-12
# cluster_filter:  35-12
# cluster_filter:  36-12
# cluster_filter:  37-12
# cluster_filter:  38-12
# cluster_filter:  39-12
# cluster_filter:  40-12
# cluster_filter:  41-12
# cluster_filter:  42-12
# cluster_filter:  43-12
# cluster_filter:  44-12
# cluster_filter:  45-12
# cluster_filter:  46-12
# cluster_filter:  47-12
# cluster_filter:  48-12
# cluster_filter:  49-12
# cluster_filter:  50-12
# cluster_filter:  51-12
# cluster_filter:  52-12
# cluster_filter:  09-13
# cluster_filter:  10-13
# cluster_filter:  11-13
# cluster_filter:  12-13
# cluster_filter:  13-13
# cluster_filter:  14-13
# cluster_filter:  15-13
# cluster_filter:  16-13
# cluster_filter:  17-13
# cluster_filter:  18-13
# cluster_filter:  19-13
# cluster_filter:  20-13
# cluster_filter:  21-13
# cluster_filter:  22-13
# cluster_filter:  23-13
# cluster_filter:  24-13
# cluster_filter:  25-13
# cluster_filter:  26-13
# cluster_filter:  27-13
# cluster_filter:  28-13
# cluster_filter:  29-13
# cluster_filter:  30-13
# cluster_filter:  31-13
# cluster_filter:  32-13
# cluster_filter:  33-13
# cluster_filter:  34-13
# cluster_filter:  35-13
# cluster_filter:  36-13
# cluster_filter:  37-13
# cluster_filter:  38-13
# cluster_filter:  39-13
# cluster_filter:  40-13
# cluster_filter:  41-13
# cluster_filter:  42-13
# cluster_filter:  43-13
# cluster_filter:  44-13
# cluster_filter:  45-13
# cluster_filter:  46-13
# cluster_filter:  47-13
# cluster_filter:  48-13
# cluster_filter:  49-13
# cluster_filter:  50-13
# cluster_filter:  51-13
# cluster_filter:  52-13
# cluster_filter:  09-14
# cluster_filter:  10-14
# cluster_filter:  11-14
# cluster_filter:  12-14
# cluster_filter:  13-14
# cluster_filter:  14-14
# cluster_filter:  15-14
# cluster_filter:  16-14
# cluster_filter:  17-14
# cluster_filter:  18-14
# cluster_filter:  19-14
# cluster_filter:  20-14
# cluster_filter:  21-14
# cluster_filter:  22-14
# cluster_filter:  23-14
# cluster_filter:  24-14
# cluster_filter:  25-14
# cluster_filter:  26-14
# cluster_filter:  27-14
# cluster_filter:  28-14
# cluster_filter:  29-14
# cluster_filter:  30-14
# cluster_filter:  31-14
# cluster_filter:  32-14
# cluster_filter:  33-14
# cluster_filter:  34-14
# cluster_filter:  35-14
# cluster_filter:  36-14
# cluster_filter:  37-14
# cluster_filter:  38-14
# cluster_filter:  39-14
# cluster_filter:  40-14
# cluster_filter:  41-14
# cluster_filter:  42-14
# cluster_filter:  43-14
# cluster_filter:  44-14
# cluster_filter:  45-14
# cluster_filter:  46-14
# cluster_filter:  47-14
# cluster_filter:  48-14
# cluster_filter:  49-14
# cluster_filter:  50-14
# cluster_filter:  51-14
# cluster_filter:  52-14
# cluster_filter:  09-15
# cluster_filter:  10-15
# cluster_filter:  11-15
# cluster_filter:  12-15
# cluster_filter:  13-15
# cluster_filter:  14-15
# cluster_filter:  15-15
# cluster_filter:  16-15
# cluster_filter:  17-15
# cluster_filter:  18-15
# cluster_filter:  19-15
# cluster_filter:  20-15
# cluster_filter:  21-15
# cluster_filter:  22-15
# cluster_filter:  23-15
# cluster_filter:  24-15
# cluster_filter:  25-15
# cluster_filter:  26-15
# cluster_filter:  27-15
# cluster_filter:  28-15
# cluster_filter:  29-15
# cluster_filter:  30-15
# cluster_filter:  31-15
# cluster_filter:  32-15
# cluster_filter:  33-15
# cluster_filter:  34-15
# cluster_filter:  35-15
# cluster_filter:  36-15
# cluster_filter:  37-15
# cluster_filter:  38-15
# cluster_filter:  39-15
# cluster_filter:  40-15
# cluster_filter:  41-15
# cluster_filter:  42-15
# cluster_filter:  43-15
# cluster_filter:  44-15
# cluster_filter:  45-15
# cluster_filter:  46-15
# cluster_filter:  47-15
# cluster_filter:  48-15
# cluster_filter:  49-15
# cluster_filter:  50-15
# cluster_filter:  51-15
# cluster_filter:  52-15
# cluster_filter:  09-16
# cluster_filter:  10-16
# cluster_filter:  11-16
# cluster_filter:  12-16
# cluster_filter:  13-16
# cluster_filter:  14-16
# cluster_filter:  15-16
# cluster_filter:  16-16
# cluster_filter:  17-16
# cluster_filter:  18-16
# cluster_filter:  19-16
# cluster_filter:  20-16
# cluster_filter:  21-16
# cluster_filter:  22-16
# cluster_filter:  23-16
# cluster_filter:  24-16
# cluster_filter:  25-16
# cluster_filter:  26-16
# cluster_filter:  27-16
# cluster_filter:  28-16
# cluster_filter:  29-16
# cluster_filter:  30-16
# cluster_filter:  31-16
# cluster_filter:  32-16
# cluster_filter:  33-16
# cluster_filter:  34-16
# cluster_filter:  35-16
# cluster_filter:  36-16
# cluster_filter:  37-16
# cluster_filter:  38-16
# cluster_filter:  39-16
# cluster_filter:  40-16
# cluster_filter:  41-16
# cluster_filter:  42-16
# cluster_filter:  43-16
# cluster_filter:  44-16
# cluster_filter:  45-16
# cluster_filter:  46-16
# cluster_filter:  47-16
# cluster_filter:  48-16
# cluster_filter:  49-16
# cluster_filter:  50-16
# cluster_filter:  51-16
# cluster_filter:  52-16
# cluster_filter:  09-17
# cluster_filter:  10-17
# cluster_filter:  11-17
# cluster_filter:  12-17
# cluster_filter:  13-17
# cluster_filter:  14-17
# cluster_filter:  15-17
# cluster_filter:  16-17
# cluster_filter:  17-17
# cluster_filter:  18-17
# cluster_filter:  19-17
# cluster_filter:  20-17
# cluster_filter:  21-17
# cluster_filter:  22-17
# cluster_filter:  23-17
# cluster_filter:  24-17
# cluster_filter:  25-17
# cluster_filter:  26-17
# cluster_filter:  27-17
# cluster_filter:  28-17
# cluster_filter:  29-17
# cluster_filter:  30-17
# cluster_filter:  31-17
# cluster_filter:  32-17
# cluster_filter:  33-17
# cluster_filter:  34-17
# cluster_filter:  35-17
# cluster_filter:  36-17
# cluster_filter:  37-17
# cluster_filter:  38-17
# cluster_filter:  39-17
# cluster_filter:  40-17
# cluster_filter:  41-17
# cluster_filter:  42-17
# cluster_filter:  43-17
# cluster_filter:  44-17
# cluster_filter:  45-17
# cluster_filter:  46-17
# cluster_filter:  47-17
# cluster_filter:  48-17
# cluster_filter:  49-17
# cluster_filter:  50-17
# cluster_filter:  51-17
# cluster_filter:  52-17

# %% [markdown]
# ### K-S analysis

# %%
flag_pass = 0.6

# %%
target = targets[1]
probe_accept = probe_accept_all[target]
lon_accept = lon_accept_all[target]
lat_accept = lat_accept_all[target]

lon_centroid = np.mean(lon_accept)
lat_centroid = np.mean(lat_accept)
index = find_nearest(lon_centroid,lat_centroid,lon_accept,lat_accept)
probe_ref = probe_accept[index]

f_sample = np.linspace(ks_f_range[0],ks_f_range[1],200,endpoint=False)
c_pick = {}
for probe in probe_accept:
    c_pick[probe] = []
    file_ds = dir_project_probes  + info_basic_probes['dir_disp'] + 'autopick_'+probe+'.txt'
    disp = np.loadtxt(file_ds,delimiter=',')
    index = np.where((disp[:,0]>=ks_f_range[0]) & (disp[:,0]<=ks_f_range[1]))[0]
    disp = disp[index,:]
    f_this = disp[:,0]
    c_this = disp[:,1]
    # 生成插值函数
    f = interpolate.interp1d(f_this,c_this,kind='cubic')
    c_pick[probe] = f(f_sample)

f_pick_ref = np.loadtxt(dir_disp_probes+'autopick_'+probe_ref+'.txt',delimiter=',')[:,0]
c_pick_ref0 = np.loadtxt(dir_disp_probes+'autopick_'+probe_ref+'.txt',delimiter=',')[:,1]
f = interpolate.interp1d(f_pick_ref,c_pick_ref0,kind='cubic')
c_pick_ref = f(f_sample)

ks_p_values = []
ks_statistic = []
for probe in probe_accept:
    ks_p_values.append(ks_2samp(c_pick[probe],c_pick_ref)[1])
    ks_statistic.append(ks_2samp(c_pick[probe],c_pick_ref)[0])

index_pass = np.array(ks_statistic)<flag_pass
probe_pass = np.array(probe_accept)[index_pass]
lon_pass = np.array(lon_accept)[index_pass]
lat_pass = np.array(lat_accept)[index_pass]
ks_statistic_pass = np.array(ks_statistic)[index_pass]

fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(121)
ax.scatter(lon_all,lat_all,c='k',s=1)
im = ax.scatter(lon_accept,lat_accept,c=ks_statistic,s=20,cmap='jet')
ax.scatter(lon_centroid,lat_centroid,c='k',s=60,marker='*',label = 'centroid')
plt.colorbar(im, ax=ax)
im.set_clim(vmin=flag_pass,vmax=1)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_xticks([])
ax.set_yticks([])

ax = fig.add_subplot(122)
ax.scatter(lon_all,lat_all,c='k',s=1)
im = ax.scatter(lon_pass,lat_pass,c=ks_statistic_pass,s=20,cmap='jet')
im.set_clim(vmin=flag_pass,vmax=1)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_xticks([])
ax.set_yticks([])
plt.colorbar(im, ax=ax)
plt.tight_layout()
