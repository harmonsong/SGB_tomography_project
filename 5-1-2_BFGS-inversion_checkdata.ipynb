# %%
import numpy as np
import os
import yaml

# %%
with open('a-project_repar.yml', 'r', encoding='utf-8') as f:
    proj = yaml.load(f.read(), Loader=yaml.FullLoader)
name_project = proj['name']
#name_project = 'project_repartrition/repartrition_01-03/'               # Harmon server
name_project
# Out:
# 'project_repartition_v4.0/output_repar_v9.5_01--10-16Hz/'

# %%
with open('0_config.yml', 'r', encoding='utf-8') as f:
    dir_config = yaml.load(f.read(), Loader=yaml.FullLoader)
dir_project_workspace = dir_config['dir_project_workspace']
dir_CC_workspace = dir_config['dir_CC_workspace']
print('dir_CC_workspace: ', dir_CC_workspace)
print('dir_project_workspace: ', dir_project_workspace)
dir_project = os.path.join(dir_project_workspace, name_project)
print('dir_project: ', dir_project)
# Out:
# dir_CC_workspace:  ./
# dir_project_workspace:  ./
# dir_project:  ./project_repartition_v4.0/output_repar_v9.5_01--10-16Hz/

# %%
filename = dir_project+'Basic_info.yml'
with open(filename, 'r', encoding='utf-8') as f:
    info_basic = yaml.load(f.read(), Loader=yaml.FullLoader)
filename_bi = dir_project+'Basic_info.npy'
info_basic_bi = np.load(filename_bi, allow_pickle='TRUE').item()      # setting dictionary

# %%
dir_data = dir_project + info_basic['rdir_disp_pick']
os.listdir(dir_data)
# Out:
# ['ds_1--08-03curve.txt',
#  'ds_10--18-03curve.txt',
#  'ds_100--07-06curve.txt',
#  'ds_101--08-06curve.txt',
#  'ds_102--10-06curve.txt',
#  'ds_103--12-06curve.txt',
#  'ds_104--13-06curve.txt',
#  'ds_105--14-06curve.txt',
#  'ds_106--17-06curve.txt',
#  'ds_107--18-06curve.txt',
#  'ds_108--20-06curve.txt',
#  'ds_109--21-06curve.txt',
#  'ds_110--22-06curve.txt',
#  'ds_111--23-06curve.txt',
#  'ds_112--24-06curve.txt',
#  'ds_113--25-06curve.txt',
#  'ds_114--26-06curve.txt',
#  'ds_115--28-06curve.txt',
#  'ds_116--29-06curve.txt',
#  'ds_117--30-06curve.txt',
#  'ds_118--31-06curve.txt',
#  'ds_12--20-03curve.txt',
#  'ds_120--34-06curve.txt',
#  'ds_121--37-06curve.txt',
#  'ds_124--40-06curve.txt',
#  'ds_125--42-06curve.txt',
#  'ds_126--43-06curve.txt',
#  'ds_127--44-06curve.txt',
#  'ds_129--46-06curve.txt',
#  'ds_13--21-03curve.txt',
#  'ds_132--49-06curve.txt',
#  'ds_133--50-06curve.txt',
#  'ds_134--51-06curve.txt',
#  'ds_135--53-06curve.txt',
#  'ds_140--13-07curve.txt',
#  'ds_143--17-07curve.txt',
#  'ds_144--18-07curve.txt',
#  'ds_145--19-07curve.txt',
#  'ds_146--20-07curve.txt',
#  'ds_147--21-07curve.txt',
#  'ds_148--22-07curve.txt',
#  'ds_149--23-07curve.txt',
#  'ds_15--23-03curve.txt',
#  'ds_150--24-07curve.txt',
#  'ds_151--25-07curve.txt',
#  'ds_152--26-07curve.txt',
#  'ds_153--27-07curve.txt',
#  'ds_154--29-07curve.txt',
#  'ds_155--30-07curve.txt',
#  'ds_156--31-07curve.txt',
#  'ds_157--32-07curve.txt',
#  'ds_158--33-07curve.txt',
#  'ds_159--34-07curve.txt',
#  'ds_160--36-07curve.txt',
#  'ds_161--37-07curve.txt',
#  'ds_162--38-07curve.txt',
#  'ds_163--39-07curve.txt',
#  'ds_164--40-07curve.txt',
#  'ds_167--43-07curve.txt',
#  'ds_168--44-07curve.txt',
#  'ds_169--45-07curve.txt',
#  'ds_17--25-03curve.txt',
#  'ds_170--46-07curve.txt',
#  'ds_171--47-07curve.txt',
#  'ds_172--48-07curve.txt',
#  'ds_175--51-07curve.txt',
#  'ds_176--52-07curve.txt',
#  'ds_177--54-07curve.txt',
#  'ds_178--07-08curve.txt',
#  'ds_179--10-08curve.txt',
#  'ds_18--26-03curve.txt',
#  'ds_180--12-08curve.txt',
#  'ds_182--16-08curve.txt',
#  'ds_183--17-08curve.txt',
#  'ds_184--18-08curve.txt',
#  'ds_185--19-08curve.txt',
#  'ds_186--20-08curve.txt',
#  'ds_187--21-08curve.txt',
#  'ds_188--22-08curve.txt',
#  'ds_189--23-08curve.txt',
#  'ds_19--27-03curve.txt',
#  'ds_191--25-08curve.txt',
#  'ds_192--26-08curve.txt',
#  'ds_193--28-08curve.txt',
#  'ds_194--29-08curve.txt',
#  'ds_195--30-08curve.txt',
#  'ds_196--31-08curve.txt',
#  'ds_197--32-08curve.txt',
#  'ds_198--33-08curve.txt',
#  'ds_199--34-08curve.txt',
#  'ds_2--09-03curve.txt',
#  'ds_20--28-03curve.txt',
#  'ds_200--35-08curve.txt',
#  'ds_201--36-08curve.txt',
#  'ds_202--37-08curve.txt',
#  'ds_203--38-08curve.txt',
#  'ds_204--39-08curve.txt',
#  'ds_205--40-08curve.txt',
#  'ds_206--41-08curve.txt',
#  'ds_207--42-08curve.txt',
#  'ds_208--43-08curve.txt',
#  'ds_209--44-08curve.txt',
#  'ds_21--29-03curve.txt',
#  'ds_210--45-08curve.txt',
#  'ds_211--46-08curve.txt',
#  'ds_212--47-08curve.txt',
#  'ds_213--48-08curve.txt',
#  'ds_214--49-08curve.txt',
#  'ds_217--52-08curve.txt',
#  'ds_218--53-08curve.txt',
#  'ds_22--30-03curve.txt',
#  'ds_220--08-09curve.txt',
#  'ds_222--10-09curve.txt',
#  'ds_223--12-09curve.txt',
#  'ds_224--13-09curve.txt',
#  'ds_225--14-09curve.txt',
#  'ds_226--16-09curve.txt',
#  'ds_227--17-09curve.txt',
#  'ds_228--18-09curve.txt',
#  'ds_229--19-09curve.txt',
#  'ds_23--31-03curve.txt',
#  'ds_231--22-09curve.txt',
#  'ds_232--23-09curve.txt',
#  'ds_233--24-09curve.txt',
#  'ds_235--26-09curve.txt',
#  'ds_236--27-09curve.txt',
#  'ds_238--29-09curve.txt',
#  'ds_239--30-09curve.txt',
#  'ds_240--31-09curve.txt',
#  'ds_241--32-09curve.txt',
#  'ds_242--33-09curve.txt',
#  'ds_243--34-09curve.txt',
#  'ds_244--35-09curve.txt',
#  'ds_245--36-09curve.txt',
#  'ds_247--38-09curve.txt',
#  'ds_248--39-09curve.txt',
#  'ds_249--40-09curve.txt',
#  'ds_251--42-09curve.txt',
#  'ds_252--43-09curve.txt',
#  'ds_253--44-09curve.txt',
#  'ds_254--45-09curve.txt',
#  'ds_255--46-09curve.txt',
#  'ds_256--47-09curve.txt',
#  'ds_257--48-09curve.txt',
#  'ds_258--49-09curve.txt',
#  'ds_259--50-09curve.txt',
#  'ds_260--51-09curve.txt',
#  'ds_261--52-09curve.txt',
#  'ds_262--53-09curve.txt',
#  'ds_263--54-09curve.txt',
#  'ds_264--12-10curve.txt',
#  'ds_265--13-10curve.txt',
#  'ds_266--14-10curve.txt',
#  'ds_267--15-10curve.txt',
#  'ds_270--19-10curve.txt',
#  'ds_271--20-10curve.txt',
#  'ds_272--21-10curve.txt',
#  'ds_273--22-10curve.txt',
#  'ds_274--23-10curve.txt',
#  'ds_275--24-10curve.txt',
#  'ds_276--25-10curve.txt',
#  'ds_277--26-10curve.txt',
#  'ds_278--27-10curve.txt',
#  'ds_279--28-10curve.txt',
#  'ds_28--36-03curve.txt',
#  'ds_280--29-10curve.txt',
#  'ds_281--30-10curve.txt',
#  'ds_282--31-10curve.txt',
#  'ds_283--32-10curve.txt',
#  'ds_284--33-10curve.txt',
#  'ds_285--34-10curve.txt',
#  'ds_286--35-10curve.txt',
#  'ds_287--36-10curve.txt',
#  'ds_289--38-10curve.txt',
#  'ds_290--39-10curve.txt',
#  'ds_291--40-10curve.txt',
#  'ds_293--42-10curve.txt',
#  'ds_294--43-10curve.txt',
#  'ds_295--44-10curve.txt',
#  'ds_298--47-10curve.txt',
#  'ds_299--48-10curve.txt',
#  'ds_3--10-03curve.txt',
#  'ds_30--41-03curve.txt',
#  'ds_300--49-10curve.txt',
#  'ds_301--50-10curve.txt',
#  'ds_302--51-10curve.txt',
#  'ds_303--52-10curve.txt',
#  'ds_304--53-10curve.txt',
#  'ds_307--08-11curve.txt',
#  'ds_309--13-11curve.txt',
#  'ds_31--42-03curve.txt',
#  'ds_310--14-11curve.txt',
#  'ds_311--16-11curve.txt',
#  'ds_313--20-11curve.txt',
#  'ds_314--21-11curve.txt',
#  'ds_315--22-11curve.txt',
#  'ds_316--23-11curve.txt',
#  'ds_317--24-11curve.txt',
#  'ds_318--25-11curve.txt',
#  'ds_319--26-11curve.txt',
#  'ds_320--27-11curve.txt',
#  'ds_322--30-11curve.txt',
#  'ds_323--31-11curve.txt',
#  'ds_324--32-11curve.txt',
#  'ds_325--33-11curve.txt',
#  'ds_326--34-11curve.txt',
#  'ds_327--35-11curve.txt',
#  'ds_328--36-11curve.txt',
#  'ds_329--37-11curve.txt',
#  'ds_330--38-11curve.txt',
#  'ds_331--39-11curve.txt',
#  'ds_332--40-11curve.txt',
#  'ds_334--42-11curve.txt',
#  'ds_335--43-11curve.txt',
#  'ds_336--44-11curve.txt',
#  'ds_337--45-11curve.txt',
#  'ds_338--46-11curve.txt',
#  'ds_339--47-11curve.txt',
#  'ds_34--47-03curve.txt',
#  'ds_340--48-11curve.txt',
#  'ds_341--49-11curve.txt',
#  'ds_342--50-11curve.txt',
#  'ds_343--51-11curve.txt',
#  'ds_344--52-11curve.txt',
#  'ds_345--53-11curve.txt',
#  'ds_346--54-11curve.txt',
#  'ds_349--10-12curve.txt',
#  'ds_35--48-03curve.txt',
#  'ds_352--14-12curve.txt',
#  'ds_353--15-12curve.txt',
#  'ds_354--16-12curve.txt',
#  'ds_355--17-12curve.txt',
#  'ds_356--19-12curve.txt',
#  'ds_357--20-12curve.txt',
#  'ds_358--21-12curve.txt',
#  'ds_359--22-12curve.txt',
#  'ds_36--52-03curve.txt',
#  'ds_360--23-12curve.txt',
#  'ds_361--24-12curve.txt',
#  'ds_362--25-12curve.txt',
#  'ds_363--26-12curve.txt',
#  'ds_364--27-12curve.txt',
#  'ds_365--29-12curve.txt',
#  'ds_366--30-12curve.txt',
#  'ds_367--31-12curve.txt',
#  'ds_368--32-12curve.txt',
#  'ds_369--33-12curve.txt',
#  'ds_37--53-03curve.txt',
#  'ds_370--34-12curve.txt',
#  'ds_372--36-12curve.txt',
#  'ds_373--37-12curve.txt',
#  'ds_374--38-12curve.txt',
#  'ds_375--39-12curve.txt',
#  'ds_376--40-12curve.txt',
#  'ds_38--07-04curve.txt',
#  'ds_381--45-12curve.txt',
#  'ds_382--46-12curve.txt',
#  'ds_383--47-12curve.txt',
#  'ds_384--48-12curve.txt',
#  'ds_385--49-12curve.txt',
#  'ds_387--51-12curve.txt',
#  'ds_388--52-12curve.txt',
#  'ds_389--53-12curve.txt',
#  'ds_39--08-04curve.txt',
#  'ds_390--54-12curve.txt',
#  'ds_391--07-13curve.txt',
#  'ds_392--09-13curve.txt',
#  'ds_398--16-13curve.txt',
#  'ds_399--17-13curve.txt',
#  'ds_4--11-03curve.txt',
#  'ds_40--09-04curve.txt',
#  'ds_400--18-13curve.txt',
#  'ds_401--19-13curve.txt',
#  'ds_402--21-13curve.txt',
#  'ds_403--22-13curve.txt',
#  'ds_404--23-13curve.txt',
#  'ds_405--24-13curve.txt',
#  'ds_406--25-13curve.txt',
#  'ds_408--27-13curve.txt',
#  'ds_409--28-13curve.txt',
#  'ds_41--10-04curve.txt',
#  'ds_410--29-13curve.txt',
#  'ds_411--30-13curve.txt',
#  'ds_412--31-13curve.txt',
#  'ds_415--34-13curve.txt',
#  'ds_417--36-13curve.txt',
#  'ds_418--37-13curve.txt',
#  'ds_419--38-13curve.txt',
#  'ds_42--12-04curve.txt',
#  'ds_420--39-13curve.txt',
#  'ds_423--42-13curve.txt',
#  'ds_424--43-13curve.txt',
#  'ds_425--44-13curve.txt',
#  'ds_427--46-13curve.txt',
#  'ds_428--47-13curve.txt',
#  'ds_429--48-13curve.txt',
#  'ds_43--13-04curve.txt',
#  'ds_430--49-13curve.txt',
#  'ds_431--50-13curve.txt',
#  'ds_433--52-13curve.txt',
#  'ds_434--53-13curve.txt',
#  'ds_435--54-13curve.txt',
#  'ds_436--07-14curve.txt',
#  'ds_437--08-14curve.txt',
#  'ds_438--09-14curve.txt',
#  'ds_44--17-04curve.txt',
#  'ds_440--13-14curve.txt',
#  'ds_442--18-14curve.txt',
#  'ds_444--20-14curve.txt',
#  'ds_445--21-14curve.txt',
#  'ds_446--22-14curve.txt',
#  'ds_45--20-04curve.txt',
#  'ds_452--32-14curve.txt',
#  'ds_453--33-14curve.txt',
#  'ds_454--34-14curve.txt',
#  'ds_455--35-14curve.txt',
#  'ds_456--36-14curve.txt',
#  'ds_457--37-14curve.txt',
#  'ds_458--38-14curve.txt',
#  'ds_46--21-04curve.txt',
#  'ds_460--40-14curve.txt',
#  'ds_461--41-14curve.txt',
#  'ds_462--42-14curve.txt',
#  'ds_463--43-14curve.txt',
#  'ds_464--44-14curve.txt',
#  'ds_465--45-14curve.txt',
#  'ds_466--46-14curve.txt',
#  'ds_468--48-14curve.txt',
#  'ds_469--49-14curve.txt',
#  'ds_470--50-14curve.txt',
#  'ds_471--51-14curve.txt',
#  'ds_472--52-14curve.txt',
#  'ds_473--53-14curve.txt',
#  'ds_474--54-14curve.txt',
#  'ds_475--07-15curve.txt',
#  'ds_476--08-15curve.txt',
#  'ds_477--10-15curve.txt',
#  'ds_48--23-04curve.txt',
#  'ds_485--21-15curve.txt',
#  'ds_489--34-15curve.txt',
#  'ds_49--24-04curve.txt',
#  'ds_490--35-15curve.txt',
#  'ds_491--36-15curve.txt',
#  'ds_492--37-15curve.txt',
#  'ds_493--38-15curve.txt',
#  'ds_494--39-15curve.txt',
#  'ds_495--40-15curve.txt',
#  'ds_496--41-15curve.txt',
#  'ds_5--12-03curve.txt',
#  'ds_50--25-04curve.txt',
#  'ds_501--46-15curve.txt',
#  'ds_502--47-15curve.txt',
#  'ds_503--48-15curve.txt',
#  'ds_504--49-15curve.txt',
#  'ds_505--50-15curve.txt',
#  'ds_506--51-15curve.txt',
#  'ds_51--27-04curve.txt',
#  'ds_510--07-16curve.txt',
#  'ds_511--08-16curve.txt',
#  'ds_512--09-16curve.txt',
#  'ds_513--10-16curve.txt',
#  'ds_514--12-16curve.txt',
#  'ds_517--19-16curve.txt',
#  'ds_52--28-04curve.txt',
#  'ds_520--33-16curve.txt',
#  'ds_521--34-16curve.txt',
#  'ds_522--35-16curve.txt',
#  'ds_523--36-16curve.txt',
#  'ds_524--37-16curve.txt',
#  'ds_527--40-16curve.txt',
#  'ds_53--29-04curve.txt',
#  'ds_531--44-16curve.txt',
#  'ds_532--45-16curve.txt',
#  'ds_534--47-16curve.txt',
#  'ds_535--48-16curve.txt',
#  'ds_536--49-16curve.txt',
#  'ds_538--51-16curve.txt',
#  'ds_539--54-16curve.txt',
#  'ds_54--30-04curve.txt',
#  'ds_540--07-17curve.txt',
#  'ds_544--12-17curve.txt',
#  'ds_545--13-17curve.txt',
#  'ds_548--17-17curve.txt',
#  'ds_549--18-17curve.txt',
#  'ds_55--31-04curve.txt',
#  'ds_551--20-17curve.txt',
#  'ds_555--34-17curve.txt',
#  'ds_556--35-17curve.txt',
#  'ds_56--32-04curve.txt',
#  'ds_564--47-17curve.txt',
#  'ds_566--50-17curve.txt',
#  'ds_567--51-17curve.txt',
#  'ds_568--53-17curve.txt',
#  'ds_569--54-17curve.txt',
#  'ds_57--33-04curve.txt',
#  'ds_570--07-18curve.txt',
#  'ds_571--08-18curve.txt',
#  'ds_572--09-18curve.txt',
#  'ds_575--12-18curve.txt',
#  'ds_576--14-18curve.txt',
#  'ds_577--15-18curve.txt',
#  'ds_58--34-04curve.txt',
#  'ds_580--18-18curve.txt',
#  'ds_581--20-18curve.txt',
#  'ds_582--34-18curve.txt',
#  'ds_583--35-18curve.txt',
#  'ds_585--37-18curve.txt',
#  'ds_587--39-18curve.txt',
#  'ds_591--47-18curve.txt',
#  'ds_592--49-18curve.txt',
#  'ds_593--50-18curve.txt',
#  'ds_595--52-18curve.txt',
#  'ds_596--53-18curve.txt',
#  'ds_597--54-18curve.txt',
#  'ds_6--13-03curve.txt',
#  'ds_60--36-04curve.txt',
#  'ds_63--47-04curve.txt',
#  'ds_65--49-04curve.txt',
#  'ds_66--52-04curve.txt',
#  'ds_67--53-04curve.txt',
#  'ds_68--08-05curve.txt',
#  'ds_69--12-05curve.txt',
#  'ds_7--14-03curve.txt',
#  'ds_70--13-05curve.txt',
#  'ds_71--14-05curve.txt',
#  'ds_72--16-05curve.txt',
#  'ds_75--22-05curve.txt',
#  'ds_76--24-05curve.txt',
#  'ds_77--26-05curve.txt',
#  'ds_78--27-05curve.txt',
#  'ds_79--28-05curve.txt',
#  'ds_8--15-03curve.txt',
#  'ds_80--29-05curve.txt',
#  'ds_81--30-05curve.txt',
#  'ds_85--36-05curve.txt',
#  'ds_86--37-05curve.txt',
#  'ds_88--39-05curve.txt',
#  'ds_89--40-05curve.txt',
#  'ds_9--16-03curve.txt',
#  'ds_91--42-05curve.txt',
#  'ds_93--44-05curve.txt',
#  'ds_98--53-05curve.txt',
#  'ds_99--54-05curve.txt',
#  'h5']

# %%
key_subworks = info_basic['key_subworks']

# %%
for file in os.listdir(dir_data):
    if '.txt' in file:
        key = file[file.find('_')+1:file.find('curve')]
        if not key in key_subworks:
            os.remove(dir_data+file)
            print('remove: ', file)
# Out:
# remove:  ds_384--48-12curve.txt
# remove:  ds_425--44-13curve.txt

# %%
for file in os.listdir(dir_data):
    if '.txt' in file:
        try:
            data = np.loadtxt(dir_data + file)
            data1 = data[(-data[:, 0]).argsort()]
            modes = set(data[:, 2].astype(int))
            # 判断是否有nan
            if np.isnan(data).any():
                print(file, ' has nan')
        except:
            print(file, ' error')
