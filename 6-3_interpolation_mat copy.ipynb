# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
from openpyxl import load_workbook
import os
import geopandas as gp
import yaml
import math

from scipy.spatial import ConvexHull
from scipy.interpolate import griddata
from shapely.geometry import Point, Polygon

from pykrige.ok import OrdinaryKriging
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from pyproj import Proj
from scipy.io import savemat

# %%
import sys
sys.path.append(r'../tools_F-J/')
from toollib_standard import plotlib

# %%
flag_project = 1 # 0--regular; 1--repartrition

# %%
if flag_project == 0:
    file_project = 'a-project.yml'
elif flag_project == 1:
    file_project = 'a-project_repar.yml'
elif flag_project == 2:
    file_project = 'a-project_voro.yml'
    
with open(file_project, 'r', encoding='utf-8') as f:
    proj = yaml.load(f.read(), Loader=yaml.FullLoader)
name_project = proj['name']

#name_project = 'project/output_FJSJ_16-01/'               
#name_project = 'project_repartrition/repartrition_01-03/'               
#name_project = 'project_voronoi/voronoi_01-03/'

# %%
with open('0_config.yml', 'r', encoding='utf-8') as f:
    dir_config = yaml.load(f.read(), Loader=yaml.FullLoader)
dir_project_workspace = dir_config['dir_project_workspace']
dir_CC_workspace = dir_config['dir_CC_workspace']
print('dir_CC_workspace: ', dir_CC_workspace)
print('dir_project_workspace: ', dir_project_workspace)
dir_project = os.path.join(dir_project_workspace, name_project)
print('dir_project: ', dir_project)
# Out:
# dir_CC_workspace:  /shdisk/rem2/Harmon/F-J/San/
# dir_project_workspace:  /shdisk/rem2/Harmon/F-J/San/
# dir_project:  /shdisk/rem2/Harmon/F-J/San/project_repartition_v4.0/output_repar_v9.2_01-01/

# %%
filename = dir_project+'Basic_info.yml'
with open(filename, 'r', encoding='utf-8') as f:
    info_basic = yaml.load(f.read(), Loader=yaml.FullLoader)
filename_bi = dir_project+'Basic_info.npy'
info_basic_bi = np.load(filename_bi, allow_pickle='TRUE').item()      # setting dictionary

# %%
dir_model_fund = dir_project + info_basic['rdir_model_fund']
dir_model = dir_project + info_basic['rdir_model']
dir_inv = dir_project + info_basic['rdir_inv_BFGS']
dir_image = dir_project + info_basic['rdir_image']+'Vs_compare/'
if not os.path.exists(dir_image):
    os.makedirs(dir_image)
dir_partition = dir_project + info_basic['rdir_partition']
key_subworks = info_basic['key_subworks']
M = len(key_subworks)
key_subworks
# Out:
# ['1--08-03',
#  '2--09-03',
#  '3--10-03',
#  '4--11-03',
#  '5--12-03',
#  '6--13-03',
#  '7--14-03',
#  '8--15-03',
#  '9--16-03',
#  '10--18-03',
#  '12--20-03',
#  '13--21-03',
#  '15--23-03',
#  '17--25-03',
#  '18--26-03',
#  '19--27-03',
#  '20--28-03',
#  '21--29-03',
#  '22--30-03',
#  '23--31-03',
#  '25--33-03',
#  '26--34-03',
#  '28--36-03',
#  '30--41-03',
#  '31--42-03',
#  '33--46-03',
#  '34--47-03',
#  '35--48-03',
#  '36--52-03',
#  '37--53-03',
#  '38--07-04',
#  '39--08-04',
#  '40--09-04',
#  '41--10-04',
#  '42--12-04',
#  '43--13-04',
#  '44--17-04',
#  '45--20-04',
#  '46--21-04',
#  '48--23-04',
#  '49--24-04',
#  '50--25-04',
#  '51--27-04',
#  '243--34-09',
#  '244--35-09',
#  '245--36-09',
#  '247--38-09',
#  '248--39-09',
#  '249--40-09',
#  '251--42-09',
#  '252--43-09',
#  '253--44-09',
#  '254--45-09',
#  '255--46-09',
#  '256--47-09',
#  '257--48-09',
#  '258--49-09',
#  '259--50-09',
#  '260--51-09',
#  '261--52-09',
#  '262--53-09',
#  '263--54-09',
#  '264--12-10',
#  '265--13-10',
#  '266--14-10',
#  '267--15-10',
#  '270--19-10',
#  '271--20-10',
#  '272--21-10',
#  '273--22-10',
#  '274--23-10',
#  '275--24-10',
#  '276--25-10',
#  '277--26-10',
#  '278--27-10',
#  '279--28-10',
#  '280--29-10',
#  '281--30-10',
#  '282--31-10',
#  '283--32-10',
#  '284--33-10',
#  '285--34-10',
#  '286--35-10',
#  '287--36-10',
#  '289--38-10',
#  '290--39-10',
#  '291--40-10',
#  '293--42-10',
#  '294--43-10',
#  '295--44-10',
#  '298--47-10',
#  '299--48-10',
#  '300--49-10',
#  '301--50-10',
#  '302--51-10',
#  '303--52-10',
#  '304--53-10',
#  '307--08-11',
#  '309--13-11',
#  '310--14-11',
#  '311--16-11',
#  '313--20-11',
#  '314--21-11',
#  '315--22-11',
#  '316--23-11',
#  '317--24-11',
#  '318--25-11',
#  '319--26-11',
#  '320--27-11',
#  '322--30-11',
#  '323--31-11',
#  '324--32-11',
#  '325--33-11',
#  '326--34-11',
#  '327--35-11',
#  '328--36-11',
#  '329--37-11',
#  '330--38-11',
#  '331--39-11',
#  '332--40-11',
#  '334--42-11',
#  '335--43-11',
#  '336--44-11',
#  '337--45-11',
#  '338--46-11',
#  '339--47-11',
#  '340--48-11',
#  '341--49-11',
#  '342--50-11',
#  '343--51-11',
#  '344--52-11',
#  '345--53-11',
#  '346--54-11',
#  '349--10-12',
#  '351--13-12',
#  '352--14-12',
#  '353--15-12',
#  '354--16-12',
#  '355--17-12',
#  '356--19-12',
#  '357--20-12',
#  '358--21-12',
#  '359--22-12',
#  '360--23-12',
#  '361--24-12',
#  '362--25-12',
#  '363--26-12',
#  '364--27-12',
#  '365--29-12',
#  '366--30-12',
#  '367--31-12',
#  '368--32-12',
#  '369--33-12',
#  '370--34-12',
#  '372--36-12',
#  '373--37-12',
#  '374--38-12',
#  '375--39-12',
#  '376--40-12',
#  '379--43-12',
#  '381--45-12',
#  '382--46-12',
#  '383--47-12',
#  '384--48-12',
#  '385--49-12',
#  '386--50-12',
#  '387--51-12',
#  '388--52-12',
#  '389--53-12',
#  '390--54-12',
#  '391--07-13',
#  '392--09-13',
#  '398--16-13',
#  '399--17-13',
#  '400--18-13',
#  '401--19-13',
#  '402--21-13',
#  '403--22-13',
#  '404--23-13',
#  '405--24-13',
#  '406--25-13',
#  '408--27-13',
#  '409--28-13',
#  '410--29-13',
#  '411--30-13',
#  '412--31-13',
#  '414--33-13',
#  '415--34-13',
#  '417--36-13',
#  '418--37-13',
#  '419--38-13',
#  '420--39-13',
#  '422--41-13',
#  '423--42-13',
#  '424--43-13',
#  '425--44-13',
#  '427--46-13',
#  '428--47-13',
#  '429--48-13',
#  '430--49-13',
#  '431--50-13',
#  '433--52-13',
#  '434--53-13',
#  '435--54-13',
#  '436--07-14',
#  '437--08-14',
#  '438--09-14',
#  '440--13-14',
#  '442--18-14',
#  '444--20-14',
#  '445--21-14',
#  '446--22-14',
#  '448--24-14',
#  '452--32-14',
#  '453--33-14',
#  '454--34-14',
#  '455--35-14',
#  '456--36-14',
#  '457--37-14',
#  '458--38-14',
#  '460--40-14',
#  '461--41-14',
#  '462--42-14',
#  '463--43-14',
#  '464--44-14',
#  '465--45-14',
#  '466--46-14',
#  '468--48-14',
#  '469--49-14',
#  '470--50-14',
#  '471--51-14',
#  '472--52-14',
#  '473--53-14',
#  '474--54-14',
#  '475--07-15',
#  '476--08-15',
#  '477--10-15',
#  '483--19-15',
#  '485--21-15',
#  '489--34-15',
#  '490--35-15',
#  '491--36-15',
#  '492--37-15',
#  '493--38-15',
#  '494--39-15',
#  '495--40-15',
#  '496--41-15',
#  '497--42-15',
#  '501--46-15',
#  '502--47-15',
#  '503--48-15',
#  '504--49-15',
#  '505--50-15',
#  '506--51-15',
#  '507--52-15',
#  '508--53-15',
#  '509--54-15',
#  '510--07-16',
#  '511--08-16',
#  '512--09-16',
#  '513--10-16',
#  '514--12-16',
#  '517--19-16',
#  '519--27-16',
#  '520--33-16',
#  '521--34-16',
#  '522--35-16',
#  '523--36-16',
#  '524--37-16',
#  '527--40-16',
#  '528--41-16',
#  '530--43-16',
#  '531--44-16',
#  '532--45-16',
#  '533--46-16',
#  '534--47-16',
#  '535--48-16',
#  '536--49-16',
#  '537--50-16',
#  '538--51-16',
#  '539--54-16',
#  '540--07-17',
#  '544--12-17',
#  '545--13-17',
#  '548--17-17',
#  '549--18-17',
#  '551--20-17',
#  '555--34-17',
#  '556--35-17',
#  '564--47-17',
#  '566--50-17',
#  '567--51-17',
#  '568--53-17',
#  '569--54-17',
#  '570--07-18',
#  '571--08-18',
#  '572--09-18',
#  '575--12-18',
#  '576--14-18',
#  '577--15-18',
#  '580--18-18',
#  '581--20-18',
#  '582--34-18',
#  '583--35-18',
#  '585--37-18',
#  '587--39-18',
#  '591--47-18',
#  '592--49-18',
#  '593--50-18',
#  '595--52-18',
#  '596--53-18',
#  '597--54-18']

# %%
dir_file = 'ModelValidCode/ModelValidCode/parameter_prepare/'

# %%
def GetStationPairs(nsta):
    StationPair = []
    for ii in range(nsta):
        for jj in range(ii+1,nsta):
            StationPair.append(ii)
            StationPair.append(jj)
    StationPair = np.array(StationPair,dtype=np.int32)
    return StationPair

# %%
stalistname_all = info_basic['stalistname_all']
stainfo = pd.read_excel(stalistname_all)
nsta_all = len(stainfo.iloc[:,0])
StationPairs_all = GetStationPairs(nsta_all)
nPairs_all = int(len(StationPairs_all)/2)
stalist_all = stainfo['Station'].tolist() 
lat_stations_all =  stainfo['latitude'].tolist() 
lon_stations_all =  stainfo['longitude'].tolist() 
elevation_stations_all = stainfo['elevation'].tolist()

# %%
stations_partition = {}
lat_stations_partition = {}
lon_stations_partition = {}
lat_centroid_partition = []
lon_centroid_partition = []
num_stations = []
for key in key_subworks:
    filepath = dir_partition + str(key) + '.txt'
    stations_this, lat_stations_this, lon_stations_this = np.loadtxt(filepath, dtype='str' , unpack=True)
    stations_partition[key] = stations_this
    lat_stations_partition[key] = lat_stations_this.astype(float)
    lon_stations_partition[key] = lon_stations_this.astype(float)
    num_stations.append(len(stations_this))
    lat_centroid_partition.append(np.mean(lat_stations_this.astype(float)))
    lon_centroid_partition.append(np.mean(lon_stations_this.astype(float)))

# %%
faults = np.load('clark_faults.npy', allow_pickle='TRUE').item()

# %% [markdown]
# ### Interpolate 3D structure

# %%
dz = 3
N = 68
num_x = 50
num_y = 50
type_interp = 'linear'
flag_save = 1 # 1--npz; 2--mat

# %%
# Read all data
struc = {}
struc_fund = {}
flag = 0
for key_subwork in key_subworks:
    file_model = dir_model + 'model_'+key_subwork+'.txt'
    file_model_fund = dir_model_fund + 'model_'+key_subwork+'.txt'
    model = np.loadtxt(file_model)
    model_fund = np.loadtxt(file_model_fund)
    struc[key_subwork] = {}
    struc[key_subwork]['layer'] = model[:, 0]
    struc[key_subwork]['z'] = model[:, 1]
    struc[key_subwork]['rho'] = model[:, 2]
    struc[key_subwork]['vs'] = model[:, 3]
    struc[key_subwork]['vp'] = model[:, 4]
    struc[key_subwork]['std'] = model[:, 5]
    struc_fund[key_subwork] = {}
    struc_fund[key_subwork]['layer'] = model_fund[:, 0]
    struc_fund[key_subwork]['z'] = model_fund[:, 1]
    struc_fund[key_subwork]['rho'] = model_fund[:, 2]
    struc_fund[key_subwork]['vs'] = model_fund[:, 3]
    struc_fund[key_subwork]['vp'] = model_fund[:, 4]
    struc_fund[key_subwork]['std'] = model_fund[:, 5]
    flag += 1
    print('Read structure model: %s (%d/%d)' % (key_subwork, flag, M))

vs_horizon = {}
vs_horizon_fund = {}
for i in range(N):
    vs_horizon[i] = []
    vs_horizon_fund[i] = []
    for key_subwork in key_subworks:
        vs_horizon[i].append(struc[key_subwork]['vs'][i])
        vs_horizon_fund[i].append(struc_fund[key_subwork]['vs'][i])
# Out:
# Read structure model: 1--08-03 (1/466)
# Read structure model: 2--09-03 (2/466)
# Read structure model: 3--10-03 (3/466)
# Read structure model: 4--11-03 (4/466)
# Read structure model: 5--12-03 (5/466)
# Read structure model: 6--13-03 (6/466)
# Read structure model: 7--14-03 (7/466)
# Read structure model: 8--15-03 (8/466)
# Read structure model: 9--16-03 (9/466)
# Read structure model: 10--18-03 (10/466)
# Read structure model: 12--20-03 (11/466)
# Read structure model: 13--21-03 (12/466)
# Read structure model: 15--23-03 (13/466)
# Read structure model: 17--25-03 (14/466)
# Read structure model: 18--26-03 (15/466)
# Read structure model: 19--27-03 (16/466)
# Read structure model: 20--28-03 (17/466)
# Read structure model: 21--29-03 (18/466)
# Read structure model: 22--30-03 (19/466)
# Read structure model: 23--31-03 (20/466)
# Read structure model: 25--33-03 (21/466)
# Read structure model: 26--34-03 (22/466)
# Read structure model: 28--36-03 (23/466)
# Read structure model: 311--16-11 (255/466)
# Read structure model: 313--20-11 (256/466)
# Read structure model: 314--21-11 (257/466)
# Read structure model: 315--22-11 (258/466)
# Read structure model: 316--23-11 (259/466)
# Read structure model: 317--24-11 (260/466)
# Read structure model: 318--25-11 (261/466)
# Read structure model: 319--26-11 (262/466)
# Read structure model: 320--27-11 (263/466)
# Read structure model: 322--30-11 (264/466)
# Read structure model: 323--31-11 (265/466)
# Read structure model: 324--32-11 (266/466)
# Read structure model: 325--33-11 (267/466)
# Read structure model: 326--34-11 (268/466)
# Read structure model: 327--35-11 (269/466)
# Read structure model: 328--36-11 (270/466)
# Read structure model: 329--37-11 (271/466)
# Read structure model: 330--38-11 (272/466)
# Read structure model: 331--39-11 (273/466)
# Read structure model: 332--40-11 (274/466)
# Read structure model: 334--42-11 (275/466)
# Read structure model: 335--43-11 (276/466)
# Read structure model: 336--44-11 (277/466)
# Read structure model: 337--45-11 (278/466)
# Read structure model: 338--46-11 (279/466)
# Read structure model: 339--47-11 (280/466)
# Read structure model: 340--48-11 (281/466)
# Read structure model: 341--49-11 (282/466)
# Read structure model: 342--50-11 (283/466)
# Read structure model: 343--51-11 (284/466)
# Read structure model: 344--52-11 (285/466)
# Read structure model: 345--53-11 (286/466)
# Read structure model: 346--54-11 (287/466)
# Read structure model: 349--10-12 (288/466)
# Read structure model: 351--13-12 (289/466)
# Read structure model: 352--14-12 (290/466)
# Read structure model: 353--15-12 (291/466)
# Read structure model: 354--16-12 (292/466)
# Read structure model: 355--17-12 (293/466)
# Read structure model: 356--19-12 (294/466)
# Read structure model: 357--20-12 (295/466)
# Read structure model: 358--21-12 (296/466)
# Read structure model: 359--22-12 (297/466)
# Read structure model: 360--23-12 (298/466)
# Read structure model: 361--24-12 (299/466)
# Read structure model: 362--25-12 (300/466)
# Read structure model: 363--26-12 (301/466)
# Read structure model: 364--27-12 (302/466)
# Read structure model: 365--29-12 (303/466)
# Read structure model: 366--30-12 (304/466)
# Read structure model: 367--31-12 (305/466)
# Read structure model: 368--32-12 (306/466)
# Read structure model: 369--33-12 (307/466)
# Read structure model: 370--34-12 (308/466)
# Read structure model: 372--36-12 (309/466)
# Read structure model: 373--37-12 (310/466)
# Read structure model: 374--38-12 (311/466)
# Read structure model: 375--39-12 (312/466)
# Read structure model: 376--40-12 (313/466)
# Read structure model: 379--43-12 (314/466)
# Read structure model: 381--45-12 (315/466)
# Read structure model: 382--46-12 (316/466)
# Read structure model: 383--47-12 (317/466)
# Read structure model: 384--48-12 (318/466)
# Read structure model: 385--49-12 (319/466)
# Read structure model: 386--50-12 (320/466)
# Read structure model: 387--51-12 (321/466)
# Read structure model: 388--52-12 (322/466)
# Read structure model: 389--53-12 (323/466)
# Read structure model: 390--54-12 (324/466)
# Read structure model: 391--07-13 (325/466)
# Read structure model: 392--09-13 (326/466)
# Read structure model: 398--16-13 (327/466)
# Read structure model: 399--17-13 (328/466)
# Read structure model: 400--18-13 (329/466)
# Read structure model: 401--19-13 (330/466)
# Read structure model: 402--21-13 (331/466)
# Read structure model: 403--22-13 (332/466)
# Read structure model: 404--23-13 (333/466)
# Read structure model: 405--24-13 (334/466)
# Read structure model: 406--25-13 (335/466)
# Read structure model: 408--27-13 (336/466)
# Read structure model: 409--28-13 (337/466)
# Read structure model: 410--29-13 (338/466)
# Read structure model: 411--30-13 (339/466)
# Read structure model: 412--31-13 (340/466)
# Read structure model: 414--33-13 (341/466)
# Read structure model: 415--34-13 (342/466)
# Read structure model: 417--36-13 (343/466)
# Read structure model: 418--37-13 (344/466)
# Read structure model: 419--38-13 (345/466)
# Read structure model: 420--39-13 (346/466)
# Read structure model: 422--41-13 (347/466)
# Read structure model: 423--42-13 (348/466)
# Read structure model: 424--43-13 (349/466)
# Read structure model: 425--44-13 (350/466)
# Read structure model: 427--46-13 (351/466)
# Read structure model: 428--47-13 (352/466)
# Read structure model: 429--48-13 (353/466)
# Read structure model: 430--49-13 (354/466)
# Read structure model: 431--50-13 (355/466)
# Read structure model: 433--52-13 (356/466)
# Read structure model: 434--53-13 (357/466)
# Read structure model: 435--54-13 (358/466)
# Read structure model: 436--07-14 (359/466)
# Read structure model: 437--08-14 (360/466)
# Read structure model: 438--09-14 (361/466)
# Read structure model: 440--13-14 (362/466)
# Read structure model: 442--18-14 (363/466)
# Read structure model: 444--20-14 (364/466)
# Read structure model: 445--21-14 (365/466)
# Read structure model: 446--22-14 (366/466)
# Read structure model: 448--24-14 (367/466)
# Read structure model: 452--32-14 (368/466)
# Read structure model: 453--33-14 (369/466)
# Read structure model: 454--34-14 (370/466)
# Read structure model: 455--35-14 (371/466)
# Read structure model: 456--36-14 (372/466)
# Read structure model: 457--37-14 (373/466)
# Read structure model: 458--38-14 (374/466)
# Read structure model: 460--40-14 (375/466)
# Read structure model: 461--41-14 (376/466)
# Read structure model: 462--42-14 (377/466)
# Read structure model: 463--43-14 (378/466)
# Read structure model: 464--44-14 (379/466)
# Read structure model: 465--45-14 (380/466)
# Read structure model: 466--46-14 (381/466)
# Read structure model: 468--48-14 (382/466)
# Read structure model: 469--49-14 (383/466)
# Read structure model: 470--50-14 (384/466)
# Read structure model: 471--51-14 (385/466)
# Read structure model: 472--52-14 (386/466)
# Read structure model: 473--53-14 (387/466)
# Read structure model: 474--54-14 (388/466)
# Read structure model: 475--07-15 (389/466)
# Read structure model: 476--08-15 (390/466)
# Read structure model: 477--10-15 (391/466)
# Read structure model: 483--19-15 (392/466)
# Read structure model: 485--21-15 (393/466)
# Read structure model: 489--34-15 (394/466)
# Read structure model: 490--35-15 (395/466)
# Read structure model: 491--36-15 (396/466)
# Read structure model: 492--37-15 (397/466)
# Read structure model: 493--38-15 (398/466)
# Read structure model: 494--39-15 (399/466)
# Read structure model: 495--40-15 (400/466)
# Read structure model: 496--41-15 (401/466)
# Read structure model: 497--42-15 (402/466)
# Read structure model: 501--46-15 (403/466)
# Read structure model: 502--47-15 (404/466)
# Read structure model: 503--48-15 (405/466)
# Read structure model: 504--49-15 (406/466)
# Read structure model: 505--50-15 (407/466)
# Read structure model: 506--51-15 (408/466)
# Read structure model: 507--52-15 (409/466)
# Read structure model: 508--53-15 (410/466)
# Read structure model: 509--54-15 (411/466)
# Read structure model: 510--07-16 (412/466)
# Read structure model: 511--08-16 (413/466)
# Read structure model: 512--09-16 (414/466)
# Read structure model: 513--10-16 (415/466)
# Read structure model: 514--12-16 (416/466)
# Read structure model: 517--19-16 (417/466)
# Read structure model: 519--27-16 (418/466)
# Read structure model: 520--33-16 (419/466)
# Read structure model: 521--34-16 (420/466)
# Read structure model: 522--35-16 (421/466)
# Read structure model: 523--36-16 (422/466)
# Read structure model: 524--37-16 (423/466)
# Read structure model: 527--40-16 (424/466)
# Read structure model: 528--41-16 (425/466)
# Read structure model: 530--43-16 (426/466)
# Read structure model: 531--44-16 (427/466)
# Read structure model: 532--45-16 (428/466)
# Read structure model: 533--46-16 (429/466)
# Read structure model: 534--47-16 (430/466)
# Read structure model: 535--48-16 (431/466)
# Read structure model: 536--49-16 (432/466)
# Read structure model: 537--50-16 (433/466)
# Read structure model: 538--51-16 (434/466)
# Read structure model: 539--54-16 (435/466)
# Read structure model: 540--07-17 (436/466)
# Read structure model: 544--12-17 (437/466)
# Read structure model: 545--13-17 (438/466)
# Read structure model: 548--17-17 (439/466)
# Read structure model: 549--18-17 (440/466)
# Read structure model: 551--20-17 (441/466)
# Read structure model: 555--34-17 (442/466)
# Read structure model: 556--35-17 (443/466)
# Read structure model: 564--47-17 (444/466)
# Read structure model: 566--50-17 (445/466)
# Read structure model: 567--51-17 (446/466)
# Read structure model: 568--53-17 (447/466)
# Read structure model: 569--54-17 (448/466)
# Read structure model: 570--07-18 (449/466)
# Read structure model: 571--08-18 (450/466)
# Read structure model: 572--09-18 (451/466)
# Read structure model: 575--12-18 (452/466)
# Read structure model: 576--14-18 (453/466)
# Read structure model: 577--15-18 (454/466)
# Read structure model: 580--18-18 (455/466)
# Read structure model: 581--20-18 (456/466)
# Read structure model: 582--34-18 (457/466)
# Read structure model: 583--35-18 (458/466)
# Read structure model: 585--37-18 (459/466)
# Read structure model: 587--39-18 (460/466)
# Read structure model: 591--47-18 (461/466)
# Read structure model: 592--49-18 (462/466)
# Read structure model: 593--50-18 (463/466)
# Read structure model: 595--52-18 (464/466)
# Read structure model: 596--53-18 (465/466)
# Read structure model: 597--54-18 (466/466)

# %%
#points = np.column_stack((lon_stations_all, lat_stations_all))
points = np.column_stack((lon_centroid_partition, lat_centroid_partition))
hull = ConvexHull(points)
polygon = Polygon(points[hull.vertices])
index_sta = []
lon_stations_in = []
lat_stations_in = []
elevation_stations_in = []
for i in range(len(lon_stations_all)):
    if polygon.contains(Point(lon_stations_all[i], lat_stations_all[i])):
        index_sta.append(i)
        lon_stations_in.append(lon_stations_all[i])
        lat_stations_in.append(lat_stations_all[i])
        elevation_stations_in.append(elevation_stations_all[i])

# %%
def compute_affine_transform(original_points, target_points):
    A_matrix = np.array([[original_points[0][0], original_points[0][1], 1, 0, 0, 0],
                         [0, 0, 0, original_points[0][0], original_points[0][1], 1],
                         [original_points[1][0], original_points[1][1], 1, 0, 0, 0],
                         [0, 0, 0, original_points[1][0], original_points[1][1], 1],
                         [original_points[2][0], original_points[2][1], 1, 0, 0, 0],
                         [0, 0, 0, original_points[2][0], original_points[2][1], 1]])

    A1_B1_C1 = np.array([target_points[0][0], target_points[0][1], target_points[1][0], target_points[1][1], target_points[2][0], target_points[2][1]])

    coefficients = np.linalg.solve(A_matrix, A1_B1_C1)

    affine_matrix = np.array([[coefficients[0], coefficients[1], coefficients[2]],
                               [coefficients[3], coefficients[4], coefficients[5]],
                               [0, 0, 1]])

    return affine_matrix

# %%
# Affine transformation
lon_stations_all_new = []
lat_stations_all_new = []
for sta in stalist_all:
    if int(sta[1:3]) <= 60:
        lon_stations_all_new.append(lon_stations_all[stalist_all.index(sta)])
        lat_stations_all_new.append(lat_stations_all[stalist_all.index(sta)])
refs = ['R0101','R6001','R6020']
lon_refs = [lon_stations_all[stalist_all.index(ref)] for ref in refs]
lat_refs = [lat_stations_all[stalist_all.index(ref)] for ref in refs]
loc_refs = np.column_stack([lon_refs,lat_refs])
loc_refs_new = np.array([[0,0],[600,0],[600,600]])

affine_matrix = compute_affine_transform(loc_refs, loc_refs_new)

# %%
# all stations
x_stations_all = []
y_stations_all = []
for i in range(len(lon_stations_all)):
    loc_sta = np.array([lon_stations_all[i],lat_stations_all[i],1])
    loc_sta_new = np.dot(affine_matrix,loc_sta)
    x_stations_all.append(loc_sta_new[0])
    y_stations_all.append(loc_sta_new[1])
# new stations
x_stations_all_new = []
y_stations_all_new = []
for i in range(len(lon_stations_all_new)):
    loc_sta = np.array([lon_stations_all_new[i],lat_stations_all_new[i],1])
    loc_sta_new = np.dot(affine_matrix,loc_sta)
    x_stations_all_new.append(loc_sta_new[0])
    y_stations_all_new.append(loc_sta_new[1])
# in stations
x_stations_in = []
y_stations_in = []
for i in range(len(lon_stations_in)):
    loc_sta = np.array([lon_stations_in[i],lat_stations_in[i],1])
    loc_sta_new = np.dot(affine_matrix,loc_sta)
    x_stations_in.append(loc_sta_new[0])
    y_stations_in.append(loc_sta_new[1])
# faults
x_faults = {}
y_faults = {}
for i in range(len(faults)):
    x_faults['clark'+str(i+1)] = []
    y_faults['clark'+str(i+1)] = []
    for j in range(len(faults['clark'+str(i+1)]['lon'])):
        loc_fault = np.array([faults['clark'+str(i+1)]['lon'][j],faults['clark'+str(i+1)]['lat'][j],1])
        loc_fault_new = np.dot(affine_matrix,loc_fault)
        x_faults['clark'+str(i+1)].append(loc_fault_new[0])
        y_faults['clark'+str(i+1)].append(loc_fault_new[1])
# partitions
x_centroid_partition = []
y_centroid_partition = []
for i in range(len(lon_centroid_partition)):
    loc_centroid = np.array([lon_centroid_partition[i],lat_centroid_partition[i],1])
    loc_centroid_new = np.dot(affine_matrix,loc_centroid)
    x_centroid_partition.append(loc_centroid_new[0])
    y_centroid_partition.append(loc_centroid_new[1])

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(121)
ax.scatter(lon_stations_all_new, lat_stations_all_new, c='k', label='Original',s = 1)
for ref in refs:
    ax.scatter(lon_stations_all[stalist_all.index(ref)], lat_stations_all[stalist_all.index(ref)], c='g', label='Original',s = 10)
for i in range(len(faults)):
    ax.plot(faults['clark'+str(i+1)]['lon'], faults['clark'+str(i+1)]['lat'], 'k')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax = fig.add_subplot(122)
ax.scatter(x_stations_all_new, y_stations_all_new, c='k', label='Original',s = 1)
for i in range(len(faults)):
    ax.plot(x_faults['clark'+str(i+1)], y_faults['clark'+str(i+1)], 'k')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(-50,650)
ax.set_ylim(-50,650)
plt.tight_layout()

# %% [markdown]
# ### Interpolate

# %%
# generate grid
xx = np.linspace(np.min(x_centroid_partition), np.max(y_centroid_partition), num_x)
yy = np.linspace(np.min(y_centroid_partition), np.max(y_centroid_partition), num_y)
A,B = np.meshgrid(xx, yy)
X_star = np.hstack((A.flatten()[:,None], B.flatten()[:,None]))
x_grid = X_star[:,0]
y_grid = X_star[:,1]

# %%
vs_inter_fund = np.zeros([len(xx),len(yy),N])
vs_inter = np.zeros([len(xx),len(yy),N])
for i in range(N):
    print('Interpolating horizon %d/%d' % (i+1,N))
    OK = OrdinaryKriging(x_centroid_partition, y_centroid_partition, vs_horizon[i], variogram_model=type_interp,nlags=3)
    zz,ss = OK.execute('grid', xx, yy)
    vs_inter[:,:,i] = zz
    OK = OrdinaryKriging(x_centroid_partition, y_centroid_partition, vs_horizon_fund[i], variogram_model=type_interp,nlags=3)
    zz,ss = OK.execute('grid', xx, yy)
    vs_inter_fund[:,:,i] = zz
# Out:
# Interpolating horizon 1/68
# Interpolating horizon 2/68
# Interpolating horizon 3/68
# Interpolating horizon 4/68
# Interpolating horizon 5/68
# Interpolating horizon 6/68
# Interpolating horizon 7/68
# Interpolating horizon 8/68
# Interpolating horizon 9/68
# Interpolating horizon 10/68
# Interpolating horizon 11/68
# Interpolating horizon 12/68
# Interpolating horizon 13/68
# Interpolating horizon 14/68
# Interpolating horizon 15/68
# Interpolating horizon 16/68
# Interpolating horizon 17/68
# Interpolating horizon 18/68
# Interpolating horizon 19/68
# Interpolating horizon 20/68
# Interpolating horizon 21/68
# Interpolating horizon 22/68
# Interpolating horizon 23/68
# Interpolating horizon 24/68
# Interpolating horizon 25/68
# Interpolating horizon 26/68
# Interpolating horizon 27/68
# Interpolating horizon 28/68
# Interpolating horizon 29/68
# Interpolating horizon 30/68
# Interpolating horizon 31/68
# Interpolating horizon 32/68
# Interpolating horizon 33/68
# Interpolating horizon 34/68
# Interpolating horizon 35/68
# Interpolating horizon 36/68
# Interpolating horizon 37/68
# Interpolating horizon 38/68
# Interpolating horizon 39/68
# Interpolating horizon 40/68
# Interpolating horizon 41/68
# Interpolating horizon 42/68
# Interpolating horizon 43/68
# Interpolating horizon 44/68
# Interpolating horizon 45/68
# Interpolating horizon 46/68
# Interpolating horizon 47/68
# Interpolating horizon 48/68
# Interpolating horizon 49/68
# Interpolating horizon 50/68
# Interpolating horizon 51/68
# Interpolating horizon 52/68
# Interpolating horizon 53/68
# Interpolating horizon 54/68
# Interpolating horizon 55/68
# Interpolating horizon 56/68
# Interpolating horizon 57/68
# Interpolating horizon 58/68
# Interpolating horizon 59/68
# Interpolating horizon 60/68
# Interpolating horizon 61/68
# Interpolating horizon 62/68
# Interpolating horizon 63/68
# Interpolating horizon 64/68
# Interpolating horizon 65/68
# Interpolating horizon 66/68
# Interpolating horizon 67/68
# Interpolating horizon 68/68

# %% [markdown]
# ### Save

# %%
def cartesian_to_geographic_2d(x, y):
    # 定义一个适当的投影，根据你的数据选择合适的投影方式
    # 这里假设使用 WGS 84 椭球体投影
    proj = Proj(proj='utm', zone=10, ellps='WGS84')
    
    # 将笛卡尔坐标系转换为经纬度,单位为米
    lon, lat = proj(x, y, inverse=True)
    
    return lon, lat

# %%
# save as npz
z = np.arange(0,N*dz,dz)
print('Save as mat')
lons = np.zeros_like(xx)
lats = np.zeros_like(yy)
for i in range(len(xx)):
    lon, lat = cartesian_to_geographic_2d(xx[i], yy[i])
    lons[i] = lon
    lats[i] = lat
lon_stations = np.zeros_like(x_stations_in)
lat_stations = np.zeros_like(y_stations_in)
for i in range(len(x_stations_in)):
    lon, lat = cartesian_to_geographic_2d(x_stations_in[i], y_stations_in[i])
    lon_stations[i] = lon
    lat_stations[i] = lat
filename = dir_file + 'Vs_inter.mat'
savemat(filename, {'vs_inter': vs_inter, 'x': lons, 'y': lats, 'z': z, 'lon_sta': lon_stations, 'lat_sta': lat_stations})
filename_fund = dir_file + 'Vs_inter_fund.mat'
savemat(filename_fund, {'vs_inter_fund': vs_inter_fund, 'x': lons, 'y': lats, 'z': z, 'lon_sta': lon_stations, 'lat_sta': lat_stations})
# Out:
# Save as mat

# %%
# save station in
lon_stations_in_new = np.zeros_like(x_stations_in)
lat_stations_in_new = np.zeros_like(y_stations_in)
for i in range(len(x_stations_in)):
    lon, lat = cartesian_to_geographic_2d(x_stations_in[i], y_stations_in[i])
    lon_stations_in_new[i] = lon
    lat_stations_in_new[i] = lat
filename = dir_file + 'sta_in.mat'
savemat(filename, {'lon_sta': lon_stations_in_new, 'lat_sta': lat_stations_in_new})

# %%
R_index = np.arange(5,19,2)
C_index = np.arange(12,54,5)
indexes = []
for row in R_index:
    for col in C_index:
        name = 'R'+str(col).zfill(2)+str(row).zfill(2)
        indexes.append(stalist_all.index(name))
stalist_in = np.array(stalist_all)[indexes]
lon_stations_virsrc = np.zeros_like(np.array(stalist_all)[indexes], dtype=float)
lat_stations_virsrc = np.zeros_like(np.array(stalist_all)[indexes], dtype=float)
for i in range(len(np.array(stalist_all)[indexes])):
    lon, lat = cartesian_to_geographic_2d(x_stations_all[indexes[i]], y_stations_all[indexes[i]])
    lon_stations_virsrc[i] = lon
    lat_stations_virsrc[i] = lat
filename = dir_file + 'sta_virsrc.mat'
savemat(filename, {'lon_sta': lon_stations_virsrc, 'lat_sta': lat_stations_virsrc})

# %%
plt.scatter(lon_stations_in_new, lat_stations_in_new, c='k', label='Original',s = 1)
plt.scatter(lon_stations_virsrc, lat_stations_virsrc, c='r', label='Original',s = 1)

# %%
plt.scatter(x_grid,y_grid,c=vs_inter[:,:,33],cmap='jet')
